# %%
import os
import re
import torch
import numpy as np
import pandas as pd
import seaborn as sns
import pandas as pandas
import matplotlib.pyplot as plt

from typing import Union

# %%
BASE_PATH_ADNI = "/data/local/kgutjahr/results/test/runs/eval/ADNI"
BASE_PATH_DVM = "/data/local/kgutjahr/results/test/runs/eval/DVM"
